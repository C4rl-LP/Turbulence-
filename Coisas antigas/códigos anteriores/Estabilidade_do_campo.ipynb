# %%
! pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.3

# %%
import os 
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from itertools import product
from tqdm import tqdm

# %% [markdown]
# # ======================================================================
# # PARÂMETROS GLOBAIS DO MODELO
# # ======================================================================

# %%
R_1 = 1            # Raio característico do nível 1
O_1 = 1            # Frequência angular base
x_1 = np.array([0, 0])  # Centro inicial (nível 1)

# Fator de escala entre frequências dos níveis
lamb = 2**(2/3)

# %% [markdown]
# # ======================================================================
# # INTEGRADOR NUMÉRICO: RUNGE-KUTTA DE 4ª ORDEM (RK4)
# # ======================================================================

# %%
def solve_RK4(func, r0, t0, dt, t_max):
    """
    Resolve o sistema dr/dt = func(t, r) usando RK4.

    Parâmetros:
    - func : função do campo vetorial
    - r0   : condição inicial (array)
    - t0   : tempo inicial
    - dt   : passo de tempo
    - t_max: tempo final
    """
    Nt = int((t_max - t0)/dt) + 1
    r = np.zeros((Nt, *r0.shape))
    t = np.zeros(Nt)

    r[0] = r0
    t[0] = t0

    for i in range(Nt - 1):
        ti = t[i]
        ri = r[i]

        k1 = func(ti, ri)
        k2 = func(ti + dt/2, ri + dt/2*k1)
        k3 = func(ti + dt/2, ri + dt/2*k2)
        k4 = func(ti + dt,   ri + dt*k3)

        r[i+1] = ri + dt/6*(k1 + 2*k2 + 2*k3 + k4)
        t[i+1] = ti + dt

    return t, r

# %% [markdown]
# # ======================================================================
# # ESTRUTURA HIERÁRQUICA DOS NÍVEIS
# # ======================================================================

# %%
def indices_nivel(n):
    """
    Gera os índices que identificam cada centro no nível n.
    O número de centros cresce como 4^(n-1).
    """
    if n == 1:
        return [[]]
    return list(product(range(4), repeat=n-1))


def R(n):
    """ Raio característico do nível n """
    return R_1 * 2**(1 - n)


def Omega(n):
    """ Frequência angular do nível n """
    return O_1 * lamb**(n - 1)


def T(n):
    """ Período associado ao nível n """
    return 2 * np.pi / Omega(n)


# ======================================================================
# GEOMETRIA DOS CENTROS
# ======================================================================

def phi(n, index):
    """
    Fase angular associada ao último índice da hierarquia.
    """
    return np.pi * (1/4 + (index[-1] - 1) / 2)


def x_centros(n, index, t):
    """
    Calcula recursivamente a posição do centro associado
    a um índice hierárquico no nível n.
    """
    if n == 1:
        return x_1

    if len(index) != n - 1:
        raise ValueError("Erro de tamanho de array")

    # Deslocamento circular do centro atual
    diff = R(n) * np.sqrt(2) * np.array([
        np.cos(Omega(n) * t + phi(n, index)),
        np.sin(Omega(n) * t + phi(n, index))
    ])

    # Soma com o centro do nível anterior
    return diff + x_centros(n - 1, index[:-1], t)

def centros_nivel(n, t):
    """
    Retorna array (N_centros, 2) com todos os centros do nível n
    """
    centros = np.array([x_1])  # nível 1

    for k in range(2, n+1):

        Rk = R(k) * np.sqrt(2)
        angle_base = Omega(k) * t

        # 4 possíveis fases
        fases = np.array([
            -np.pi/4,
             np.pi/4,
             3*np.pi/4,
             5*np.pi/4
        ])

        deslocamentos = Rk * np.column_stack([
            np.cos(angle_base + fases),
            np.sin(angle_base + fases)
        ])

        # Produto cartesiano vetorizado
        centros = (
            centros[:, None, :] + deslocamentos[None, :, :]
        ).reshape(-1, 2)

    return centros

# %% [markdown]
# # ======================================================================
# # DEFINIÇÃO DO CAMPO VETORIAL
# # ======================================================================

# %%
def campo(x, y, t, n, index):
    """
    Campo vetorial induzido por um único centro
    do nível n nos pontos (x, y).
    """
    x_centro_n = x_centros(n, index, t)

    # Diferenças vetoriais (arrays)
    dx = x - x_centro_n[0]
    dy = y - x_centro_n[1]

    # Parâmetro do corte espacial
    alpha = 3
    r2_cut = alpha**2 * R(n)**2

    # Máscara booleana: partículas suficientemente próximas
    mask = dx**2 + dy**2 <= r2_cut

    # Inicializa o campo como zero
    vx = np.zeros_like(x)
    vy = np.zeros_like(y)

    # Se nenhuma partícula estiver dentro do raio, retorna zero direto
    if not np.any(mask):
        return vx, vy

    # Fator radial (somente onde o campo é relevante)
    factor = -(dx[mask]**2 + dy[mask]**2) * 2 / R(n)**2

    # Intensidade do campo
    poten = 2 * np.pi * np.exp(factor - 1) / T(n)

    # Campo rotacional
    vx[mask] = -dy[mask] * poten
    vy[mask] =  dx[mask] * poten

    return vx, vy


def campo_total(x, y, t, n_max=3):
    """
    Soma o campo vetorial de todos os níveis
    e todos os centros hierárquicos.
    """
    Vx = np.zeros_like(x)
    Vy = np.zeros_like(y)

    for n in range(1, n_max + 1):
        for idx in indices_nivel(n):
            vx, vy = campo(x, y, t, n, list(idx))
            Vx += vx
            Vy += vy

    return Vx, Vy

# %%
import numpy as np

def campo_total_otimizado(X, Y, t, n_max=3):

    Vx = np.zeros_like(X)
    Vy = np.zeros_like(Y)

    # Pré-calcula todos os centros uma única vez
    centros = []
    for n in range(1, n_max + 1):
        Rn = 2 * R(n)
        Tn = T(n)
        for idx in indices_nivel(n):
            xc, yc = x_centros(n, list(idx), t)
            centros.append((xc, yc, Rn, Tn))

    # Loop apenas nos centros (agora sem chamadas caras)
    for xc, yc, Rn, Tn in centros:

        # Bounding box (reduz drasticamente custo)
        mask_box = (
            (X > xc - Rn) & (X < xc + Rn) &
            (Y > yc - Rn) & (Y < yc + Rn)
        )

        if not np.any(mask_box):
            continue

        Xloc = X[mask_box]
        Yloc = Y[mask_box]

        dx = Xloc - xc
        dy = Yloc - yc
        r2 = dx**2 + dy**2

        mask = r2 < Rn**2
        if not np.any(mask):
            continue

        # Computa apenas onde realmente importa
        expo = np.exp(1 / ((r2[mask] / Rn**2) - 1))
        pot = (2*np.pi / Tn) * expo

        Vx_loc = np.zeros_like(dx)
        Vy_loc = np.zeros_like(dy)

        Vx_loc[mask] = -dy[mask] * pot
        Vy_loc[mask] =  dx[mask] * pot

        Vx[mask_box] += Vx_loc
        Vy[mask_box] += Vy_loc

    return Vx, Vy

import numpy as np
import matplotlib.pyplot as plt

def mapa_intensidade(t=0.0, N_fields=3, L=5, resolucao=400):

    # Grade
    x = np.linspace(-L, L, resolucao)
    y = np.linspace(-L, L, resolucao)
    X, Y = np.meshgrid(x, y)

    # Campo
    Vx, Vy = campo_total_2(X, Y, t, N_fields)

    # Intensidade
    V = np.sqrt(Vx**2 + Vy**2)

    plt.figure(figsize=(8,8))

    mapa = plt.pcolormesh(
        X, Y, V,
        shading='auto',
        cmap='inferno'
    )

    plt.colorbar(mapa, label='|V|')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'Mapa de intensidade do campo (t = {t})')
    plt.axis('equal')
    plt.show()


# Chamada
mapa_intensidade(t=0.0, N_fields=3, L=5, resolucao=500)

# %% [markdown]
# # ======================================================================
# # SIMULAÇÃO DE PARTÍCULAS
# # ======================================================================

# %%
# Out:
# array([[0.3       , 0.5       ],
#        [0.25417178, 0.48120137],
#        [0.33428798, 0.49173809],
#        [0.29015898, 0.48108072],
#        [0.3179686 , 0.4770013 ],
#        [0.33292613, 0.51758099],
#        [0.2725301 , 0.53658654],
#        [0.32189273, 0.52959416],
#        [0.29579833, 0.54392204],
#        [0.26863267, 0.50239368]])

# %% [markdown]
# # ======================================================================
# # SIMULAÇÕES AUXILIARES: CAMPO CONGELADO E CAMPO MÓVEL
# # ======================================================================

# %%
def simular_particula_campo_congelado(
    r0, 
    N_fields, 
    t_freeze=0.0, 
    dt=0.01, 
    t_max=10
):
    """
    Simula uma partícula em um campo congelado
    em um instante fixo t = t_freeze.
    """
    def funcao(t, r):
        x = r[:, 0]
        y = r[:, 1]
        Vx, Vy = campo_total(x, y, t_freeze, N_fields)
        return np.column_stack((Vx, Vy))

    t, r = solve_RK4(funcao, r0, 0.0, dt, t_max)
    return t, r


def simular_particula_campo_movel(
    r0, 
    N_fields, 
    dt=0.01, 
    t_max=10
):
    """
    Simula uma partícula em um campo dependente do tempo.
    """
    def funcao(t, r):
        x = r[:, 0]
        y = r[:, 1]
        Vx, Vy = campo_total(x, y, t, N_fields)
        return np.column_stack((Vx, Vy))

    t, r = solve_RK4(funcao, r0, 0.0, dt, t_max)
    return t, r

# %% [markdown]
# # ======================================================================
# # EXECUÇÃO DAS SIMULAÇÕES
# # ======================================================================

# %%
r0 = np.array([[np.pi/6, np.sqrt(2)/4]])
N_fields = 3

'''# Campo dependente do tempo
t1, r_movel = simular_particula_campo_movel(
    r0,
    N_fields=N_fields,
    dt=0.01,
    t_max=10
)

# Campo congelado
t2, r_congelado = simular_particula_campo_congelado(
    r0,
    N_fields=N_fields,
    t_freeze=0.0,
    dt=0.01,
    t_max=10
)

# Nuvem de partículas
ts, rs = simular_particulas(
    N=3,
    N_fields=N_fields,
    dimensao_quadrado=0.05,
    r0=r0,
    dt=0.01,pasta_saida="estabilidade"
    t_max=20
)'''



def testar_estabilidade(
    nivel_max,
    
    N_particulas,
    r0,
    pasta_saida="estabilidade",
    nivel_min = 1
):
    """
    Testa a estabilidade do ponto r0 para diferentes números de níveis do campo.
    Para cada nível n:
      - simula uma nuvem de partículas ao redor de r0
      - plota as trajetórias
      - salva a figura em disco
    """

    os.makedirs(pasta_saida, exist_ok=True)

    for n in tqdm(
        range(nivel_min, nivel_max + 1),
        desc="Testando níveis",
        unit="nível"
    ):


        # Escalas naturais do nível
        L = R(n) / 8               # tamanho da nuvem inicial
        dt = 0.08 * R(n)             # passo temporal
        t_max = 5         # tempo total (alguns períodos)

        print(f"Testando estabilidade para n = {n}")

        ts, rs = simular_particulas(
            N=N_particulas,
            N_fields=n,
            dimensao_quadrado=L,
            r0=r0,
            dt=dt,
            t_max=t_max
        )

        # rs tem shape (Nt, N, 2)
        Nt = rs.shape[0]

        plt.figure(figsize=(6, 6))


        cores = plt.cm.viridis(np.linspace(0, 1, N_particulas))

        for i in range(N_particulas):
            # Trajetória
            plt.plot(
                rs[:, i, 0],
                rs[:, i, 1],
                lw=1,
                alpha=0.4,
                color=cores[i]
            )

            # Ponto inicial (vazado)
            plt.scatter(
                rs[0, i, 0],
                rs[0, i, 1],
                facecolors="none",
                edgecolors=cores[i],
                s=30,
                linewidths=1.5
            )

            # Ponto final (bem visível)
            plt.scatter(
                rs[-1, i, 0],
                rs[-1, i, 1],
                color=cores[i],
                s=30,
                zorder=3
            )

        # Ponto central
        plt.scatter(
            r0[0, 0],
            r0[0, 1],
            c="red",
            s=100,
            marker="x",
            linewidths=2,
            label="ponto r0"
        )

        plt.axis("equal")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title(f"Estabilidade em torno de r0 — Níveis até n = {n}")
        plt.legend()
        plt.grid(alpha=0.3)


        nome_arquivo = os.path.join(
            pasta_saida,
            f"estabilidade_nivel_{n}_em_x{r0[0,0]:.2f}_y{r0[0,1]:.2f}em.png"
        )
        plt.savefig(nome_arquivo, dpi=200)
        plt.close()

        print(f"Imagem salva em: {nome_arquivo}")



# ======================================================================
# EXTRAÇÃO DOS DADOS PARA PLOT
# ======================================================================

'''x_m, y_m = r_movel[:, 0, 0], r_movel[:, 0, 1]
x_c, y_c = r_congelado[:, 0, 0], r_congelado[:, 0, 1]
x_s, y_s = rs[:, :, 0], rs[:, :, 1]


# ======================================================================
# VISUALIZAÇÃO
# ======================================================================

plt.figure(figsize=(6, 6))

plt.plot(x_m, y_m, label='Campo dependente do tempo')
plt.plot(x_c, y_c, '--', label='Campo congelado (t = 0)')
plt.plot(x_s, y_s)

plt.scatter(x_m[0], y_m[0], color='green', s=50, label='Início')
plt.scatter(x_m[-1], y_m[-1], color='red', s=50, label='Fim')
plt.scatter(x_c[-1], y_c[-1], color='purple', s=50, label='Fim do congelado')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Comparação: campo móvel vs campo congelado')
plt.axis('equal')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.grid()
plt.legend()
plt.show()'''
# Out:
# "x_m, y_m = r_movel[:, 0, 0], r_movel[:, 0, 1]\nx_c, y_c = r_congelado[:, 0, 0], r_congelado[:, 0, 1]\nx_s, y_s = rs[:, :, 0], rs[:, :, 1]\n\n\n# ======================================================================\n# VISUALIZAÇÃO\n# ======================================================================\n\nplt.figure(figsize=(6, 6))\n\nplt.plot(x_m, y_m, label='Campo dependente do tempo')\nplt.plot(x_c, y_c, '--', label='Campo congelado (t = 0)')\nplt.plot(x_s, y_s)\n\nplt.scatter(x_m[0], y_m[0], color='green', s=50, label='Início')\nplt.scatter(x_m[-1], y_m[-1], color='red', s=50, label='Fim')\nplt.scatter(x_c[-1], y_c[-1], color='purple', s=50, label='Fim do congelado')\n\nplt.xlabel('x')\nplt.ylabel('y')\nplt.title('Comparação: campo móvel vs campo congelado')\nplt.axis('equal')\nplt.xlim(-1, 1)\nplt.ylim(-1, 1)\nplt.grid()\nplt.legend()\nplt.show()"

# %%
r0 = np.array([[np.pi/6, np.sqrt(2)/4]])

testar_estabilidade(
    nivel_max=1,
    N_particulas=1,
    r0=r0,
    nivel_min = 5
)
# Out:
# Testando níveis:   0%|          | 0/4 [00:00<?, ?nível/s]
# Testando estabilidade para n = 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 r0 = np.array([[np.pi/6, np.sqrt(2)/4]])
# ----> 3 testar_estabilidade(
#       4     nivel_max=8,
#       5     N_particulas=50,
#       6     r0=r0,
#       7     nivel_min = 5
#       8 )
#
# Cell In[10], line 65, in testar_estabilidade(nivel_max, N_particulas, r0, pasta_saida, nivel_min)
#      61 t_max = 5         # tempo total (alguns períodos)
#      63 print(f"Testando estabilidade para n = {n}")
# ---> 65 ts, rs = simular_particulas(
#      66     N=N_particulas,
#      67     N_fields=n,
#      68     dimensao_quadrado=L,
#      69     r0=r0,
#      70     dt=dt,
#      71     t_max=t_max
#      72 )
#      74 # rs tem shape (Nt, N, 2)
#      75 Nt = rs.shape[0]
#
# Cell In[8], line 33, in simular_particulas(N, N_fields, dimensao_quadrado, r0, dt, t_max)
#      30 # adiciona a partícula central exatamente em r0
#      31 particle_t0 = np.vstack((r0,particle_t0))
# ---> 33 t, r = solve_RK4(funcao, particle_t0, 0.0, dt, t_max)
#      34 return t, r
#
# Cell In[5], line 23, in solve_RK4(func, r0, t0, dt, t_max)
#      20 ti = t[i]
#      21 ri = r[i]
# ---> 23 k1 = func(ti, ri)
#      24 k2 = func(ti + dt/2, ri + dt/2*k1)
#      25 k3 = func(ti + dt/2, ri + dt/2*k2)
#
# Cell In[8], line 12, in simular_particulas.<locals>.funcao(t, r)
#      10 x = r[:, 0]
#      11 y = r[:, 1]
# ---> 12 Vx, Vy = campo_total(x, y, t, N_fields)
#      13 return np.column_stack((Vx, Vy))
#
# Cell In[7], line 50, in campo_total(x, y, t, n_max)
#      48 for n in range(1, n_max + 1):
#      49     for idx in indices_nivel(n):
# ---> 50         vx, vy = campo(x, y, t, n, list(idx))
#      51         Vx += vx
#      52         Vy += vy
#
# Cell In[7], line 10, in campo(x, y, t, n, index)
#       8 # Diferenças vetoriais (arrays)
#       9 dx = x - x_centro_n[0]
# ---> 10 dy = y - x_centro_n[1]
#      12 # Parâmetro do corte espacial
#      13 alpha = 3
#
# KeyboardInterrupt:

# %%
def testar_convergencia_radial(
    nivel_max,
    N_particulas,
    r0,
    pasta_saida="convergencia_radial",
    nivel_min=1,
    usar_raio="max"  # "max" ou "mean"
):
    """
    Testa convergência radial em torno do ponto fixo r0.
    
    Para cada nível n:
      - simula uma nuvem inicial
      - plota apenas os pontos finais
      - desenha o círculo inicial e o círculo final
      - calcula fator de contração radial

    Retorna:
      dict com métricas de estabilidade por nível
    """

    os.makedirs(pasta_saida, exist_ok=True)

    resultados = {
        "nivel": [],
        "R_ini": [],
        "R_fin": [],
        "fator_contracao": []
    }

    for n in range(nivel_min, nivel_max + 1):

        print(f"\nTestando convergência radial para n = {n}")

        # Escalas naturais
        L = R(n) / 8
        dt = 0.08 * R(n)
        t_max = 5

        ts, rs = simular_particulas(
            N=N_particulas,
            N_fields=n,
            dimensao_quadrado=L,
            r0=r0,
            dt=dt,
            t_max=t_max
        )

        # Pontos iniciais e finais
        r_ini = rs[0,:,:]      # (N, 2)
        r_fin = rs[-1,:,:]     # (N, 2)
        r_0 = rs[:,0,:]
        
        # Distâncias ao ponto fixo
        dist_ini = np.linalg.norm(r_ini - r0, axis=1)
        dist_fin = np.linalg.norm(r_fin - r_0[-1,:], axis=1)

        R_ini = dist_ini.max()

        if usar_raio == "mean":
            R_fin = dist_fin.mean()
        else:
            R_fin = dist_fin.max()

        fator = R_fin / R_ini

        # Salva métricas
        resultados["nivel"].append(n)
        resultados["R_ini"].append(R_ini)
        resultados["R_fin"].append(R_fin)
        resultados["fator_contracao"].append(fator)

        # ===============================
        # PLOT
        # ===============================
        plt.figure(figsize=(6, 6))

        # Pontos finais
        plt.scatter(
            r_fin[:, 0],
            r_fin[:, 1],
            s=40,
            alpha=0.8,
            label="pontos finais"
        )


        plt.scatter(
            r_0[-1, 0],
            r_0[-1, 1],
            c="red",
            s=100,
            marker="x",
            label="ponto fixo r0 no final"
        )

        theta = np.linspace(0, 2*np.pi, 400)

        # Círculo inicial
        plt.plot(
            r_0[-1, 0] + R_ini * np.cos(theta),
            r_0[-1, 1] + R_ini * np.sin(theta),
            "--",
            lw=2,
            label=f"R inicial = {R_ini:.2e}"
        )

        # Círculo final
        plt.plot(
            r_0[-1, 0] + R_fin * np.cos(theta),
            r_0[-1, 1] + R_fin * np.sin(theta),
            lw=2,
            label=f"R final = {R_fin:.2e}"
        )

        plt.axis("equal")
        plt.grid(alpha=0.3)
        plt.legend()
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title(
            f"Convergência radial — n = {n}\n"
            f"R_fin / R_ini = {fator:.3f}"
        )

        nome_arquivo = os.path.join(
            pasta_saida,
            f"convergencia_radial_n{n}_x{r0[0,0]:.2f}_y{r0[0,1]:.2f}.png"
        )

        plt.savefig(nome_arquivo, dpi=200)
        plt.close()

        print(f"→ fator de contração = {fator:.3f}")
        print(f"Imagem salva em: {nome_arquivo}")

    return resultados
res = testar_convergencia_radial(
    nivel_max=8,
    N_particulas=100,
    r0=r0
)

plt.plot(res["nivel"], res["fator_contracao"], "-o")
plt.axhline(1, ls="--", c="k")
plt.xlabel("nível n")
plt.ylabel("R_final / R_inicial")
plt.grid(alpha=0.3)
# Out:
# Testando convergência radial para n = 1
# → fator de contração = 1.807
# Imagem salva em: convergencia_radial/convergencia_radial_n1_x0.52_y0.35.png
#
# Testando convergência radial para n = 2
# → fator de contração = 1.126
# Imagem salva em: convergencia_radial/convergencia_radial_n2_x0.52_y0.35.png
#
# Testando convergência radial para n = 3
# → fator de contração = 1.077
# Imagem salva em: convergencia_radial/convergencia_radial_n3_x0.52_y0.35.png
#
# Testando convergência radial para n = 4
# → fator de contração = 1.160
# Imagem salva em: convergencia_radial/convergencia_radial_n4_x0.52_y0.35.png
#
# Testando convergência radial para n = 5
# → fator de contração = 1.191
# Imagem salva em: convergencia_radial/convergencia_radial_n5_x0.52_y0.35.png
#
# Testando convergência radial para n = 6
# → fator de contração = 1.320
# Imagem salva em: convergencia_radial/convergencia_radial_n6_x0.52_y0.35.png
#
# Testando convergência radial para n = 7
# → fator de contração = 1.552
# Imagem salva em: convergencia_radial/convergencia_radial_n7_x0.52_y0.35.png
#
# Testando convergência radial para n = 8
# → fator de contração = 2.796
# Imagem salva em: convergencia_radial/convergencia_radial_n8_x0.52_y0.35.png

# %% [markdown]
# Vamos usar a bump function

# %%
def campo_2(x, y, t, n, index):
    """
    Campo vetorial induzido por um único centro
    do nível n nos pontos (x, y).
    """
    x_centro_n = x_centros(n, index, t)

    # Diferenças vetoriais (arrays)
    dx = x - x_centro_n[0]
    dy = y - x_centro_n[1]
    r2 = dx**2 + dy**2
    R2 = np.sqrt(2)*R(n)**2

    vx= np.zeros_like(dx)
    vy = np.zeros_like(dy)

    poten = np.zeros_like(r2)

    mask = r2 < R2

    if np.any(mask):
        poten[mask] = (
            2*np.pi
            * np.exp(0.8 / ((r2[mask] / R2) - 1))
            / T(n)
        )
    vx[mask] = -dy[mask] * poten[mask]
    vy[mask] = dx[mask] * poten[mask]

    return vx, vy

def campo_total_2(x, y, t, n_max=3):
    """
    Soma o campo vetorial de todos os níveis
    e todos os centros hierárquicos.
    """
    Vx = np.zeros_like(x)
    Vy = np.zeros_like(y)

    for n in range(1, n_max + 1):
        for idx in indices_nivel(n):
            vx, vy = campo_2(x, y, t, n, list(idx))
            Vx += vx
            Vy += vy

    return Vx, Vy






def campo_total_super(x, y, t, n_max=3):

    Nx = len(x)
    Ny = len(y)

    Vx = np.zeros((Ny, Nx))
    Vy = np.zeros((Ny, Nx))

    dx_grid = x[1] - x[0]
    dy_grid = y[1] - y[0]

    for n in range(1, n_max+1):

        centros = centros_nivel(n, t)
        Rn =  np.sqrt(2)*R(n)
        Tn = T(n)

        for xc, yc in centros:

            ix_min = max(0, int((xc - Rn - x[0]) / dx_grid))
            ix_max = min(Nx-1, int((xc + Rn - x[0]) / dx_grid))

            iy_min = max(0, int((yc - Rn - y[0]) / dy_grid))
            iy_max = min(Ny-1, int((yc + Rn - y[0]) / dy_grid))

            if ix_min >= ix_max or iy_min >= iy_max:
                continue

            x_sub = x[ix_min:ix_max+1]
            y_sub = y[iy_min:iy_max+1]

            Xsub, Ysub = np.meshgrid(x_sub, y_sub)

            dx = Xsub - xc
            dy = Ysub - yc
            r2 = dx*dx + dy*dy

            mask = r2 < Rn*Rn
            if not np.any(mask):
                continue

            expo = np.zeros_like(r2)
            expo[mask] = np.exp(.7 / ((r2[mask] / (Rn*Rn)) - 1))

            pot = (2*np.pi / Tn) * expo

            Vx[iy_min:iy_max+1, ix_min:ix_max+1] += -dy * pot
            Vy[iy_min:iy_max+1, ix_min:ix_max+1] +=  dx * pot

    return Vx, Vy


def simular_particulas_2(N, N_fields, dimensao_quadrado, r0, dt=0.01, t_max=1):
    """
    Simula N partículas em um pequeno quadrado
    ao redor da posição inicial r0.
    """

    def funcao(t, r):
        x = r[:, 0]
        y = r[:, 1]
        Vx, Vy = campo_total_2(x, y, t, N_fields)
        return np.column_stack((Vx, Vy))

    L = dimensao_quadrado

    # Distribuição inicial uniforme em um círculo de raio L/2
    R0 = L / 2

    theta = np.random.uniform(0, 2*np.pi, size=N-1)
    u = np.random.uniform(0, 1, size=N-1)

    r = R0 * np.sqrt(u)

    dx = r * np.cos(theta)
    dy = r * np.sin(theta)

    particle_t0 = r0 + np.column_stack((dx, dy))

    # adiciona a partícula central exatamente em r0
    particle_t0 = np.vstack((r0,particle_t0))

    t, r = solve_RK4(funcao, particle_t0, 0.0, dt, t_max)
    return t, r

def simular_particulas_2_static(N, N_fields, dimensao_quadrado, r0, dt=0.01, t_max=1):
    """
    Simula N partículas em um pequeno quadrado
    ao redor da posição inicial r0.
    """

    def funcao(t, r):
        x = r[:, 0]
        y = r[:, 1]
        Vx, Vy = campo_total_2(x, y, 0, N_fields)
        return np.column_stack((Vx, Vy))

    L = dimensao_quadrado

    # Distribuição inicial uniforme em um círculo de raio L/2
    R0 = L / 2

    theta = np.random.uniform(0, 2*np.pi, size=N-1)
    u = np.random.uniform(0, 1, size=N-1)

    r = R0 * np.sqrt(u)

    dx = r * np.cos(theta)
    dy = r * np.sin(theta)

    particle_t0 = r0 + np.column_stack((dx, dy))

    # adiciona a partícula central exatamente em r0
    particle_t0 = np.vstack((r0,particle_t0))

    t, r = solve_RK4(funcao, particle_t0, 0.0, dt, t_max)
    return t, r

# %%
def plot_campo(t=0.0, N_fields=3, L=5, resolucao=200):

    x = np.linspace(-L, L, resolucao)
    y = np.linspace(-L, L, resolucao)

    Vx, Vy = campo_total_super(x, y, t, N_fields)

    X, Y = np.meshgrid(x, y)
    V = np.sqrt(Vx**2 + Vy**2)

    plt.figure(figsize=(8,8))

    # Streamplot (mais bonito para campos suaves)
    plt.streamplot(X, Y, Vx, Vy, 
                   color=V, 
                   cmap='viridis', 
                   density=2.5)

    plt.colorbar(label='|V|')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'Campo vetorial com nível {N_fields}')
    plt.axis('equal')
    plt.show()

# Chamada
plot_campo(t=0.25, N_fields=3, L=1.2, resolucao=150)

# %%
def mapa_intensidade(t=0.0, N_fields=3, L=1, resolucao=250):

    x = np.linspace(-L, L, resolucao)
    y = np.linspace(-L, L, resolucao)

    Vx, Vy = campo_total_super(x, y, t, N_fields)

    X, Y = np.meshgrid(x, y)
    V = np.sqrt(Vx**2 + Vy**2)

    plt.figure(figsize=(7,7))
    plt.pcolormesh(X, Y, V, shading='auto', cmap='inferno')
    plt.colorbar(label='|V|')
    plt.axis('equal')
    plt.show()
# Chamada
mapa_intensidade(t=0.0, N_fields=1, L=1.3, resolucao=250)

# %%
def mapa_vorticidade_analitica(t=0.0, N_fields=3, L=1, resolucao=250):

    c = 0.7

    x = np.linspace(-L, L, resolucao)
    y = np.linspace(-L, L, resolucao)

    X, Y = np.meshgrid(x, y)
    omega_total = np.zeros_like(X)

    for n in range(1, N_fields+1):

        centros = centros_nivel(n, t)
        Rn = np.sqrt(2) * R(n)
        Tn = T(n)
        R2 = Rn * Rn

        for xc, yc in centros:

            dx = X - xc
            dy = Y - yc
            r2 = dx*dx + dy*dy

            u = r2 / R2
            mask = u < 1.0
            if not np.any(mask):
                continue

            u_local = u[mask]

            # bump
            expo = np.exp(-c / (1 - u_local))

            pref = 2*np.pi / Tn

            omega = pref * expo * (
                2 - (2*c * u_local) / (1 - u_local)**2
            )

            omega_total[mask] += omega

    plt.figure(figsize=(7,7))
    plt.pcolormesh(X, Y, omega_total, shading='auto', cmap='RdBu_r')
    plt.colorbar(label='ω')
    plt.axis('equal')
    plt.title(f'Vorticidade com nível {N_fields}')
    plt.show()

mapa_vorticidade_analitica(t=0.0, N_fields=10, L=1.2, resolucao=330)

# %%
def testar_convergencia_radial(
    nivel_max,
    N_particulas,
    r0,
    pasta_saida="convergencia_radial_2",
    nivel_min=1,
    usar_raio="max"  # "max" ou "mean"
):
    """
    Testa convergência radial em torno do ponto fixo r0.
    
    Para cada nível n:
      - simula uma nuvem inicial
      - plota apenas os pontos finais
      - desenha o círculo inicial e o círculo final
      - calcula fator de contração radial

    Retorna:
      dict com métricas de estabilidade por nível
    """

    os.makedirs(pasta_saida, exist_ok=True)

    resultados = {
        "nivel": [],
        "R_ini": [],
        "R_fin": [],
        "fator_contracao": []
    }

    for n in range(nivel_min, nivel_max + 1):

        print(f"\nTestando convergência radial para n = {n}")

        # Escalas naturais
        L = R(n) / 16
        dt = 0.08 * R(n)
        t_max = 5

        ts, rs = simular_particulas_2(
            N=N_particulas,
            N_fields=n,
            dimensao_quadrado=L,
            r0=r0,
            dt=dt,
            t_max=t_max
        )

        # Pontos iniciais e finais
        r_ini = rs[0,:,:]      # (N, 2)
        r_fin = rs[-1,:,:]     # (N, 2)
        r_0 = rs[:,0,:]
        
        # Distâncias ao ponto fixo
        dist_ini = np.linalg.norm(r_ini - r0, axis=1)
        dist_fin = np.linalg.norm(r_fin - r_0[-1,:], axis=1)

        R_ini = dist_ini.max()

        if usar_raio == "mean":
            R_fin = dist_fin.mean()
        else:
            R_fin = dist_fin.max()

        fator = R_fin / R_ini

        # Salva métricas
        resultados["nivel"].append(n)
        resultados["R_ini"].append(R_ini)
        resultados["R_fin"].append(R_fin)
        resultados["fator_contracao"].append(fator)

        # ===============================
        # PLOT
        # ===============================
        plt.figure(figsize=(6, 6))

        # Pontos finais
        plt.scatter(
            r_fin[:, 0],
            r_fin[:, 1],
            s=40,
            alpha=0.8,
            label="pontos finais"
        )


        plt.scatter(
            r_0[-1, 0],
            r_0[-1, 1],
            c="red",
            s=100,
            marker="x",
            label="ponto fixo r0 no final"
        )

        theta = np.linspace(0, 2*np.pi, 400)

        # Círculo inicial
        plt.plot(
            r_0[-1, 0] + R_ini * np.cos(theta),
            r_0[-1, 1] + R_ini * np.sin(theta),
            "--",
            lw=2,
            label=f"R inicial = {R_ini:.2e}"
        )

        # Círculo final
        plt.plot(
            r_0[-1, 0] + R_fin * np.cos(theta),
            r_0[-1, 1] + R_fin * np.sin(theta),
            lw=2,
            label=f"R final = {R_fin:.2e}"
        )

        plt.axis("equal")
        plt.grid(alpha=0.3)
        plt.legend()
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title(
            f"Convergência radial — n = {n}\n"
            f"R_fin / R_ini = {fator:.3f}"
        )

        nome_arquivo = os.path.join(
            pasta_saida,
            f"convergencia_radial_n{n}_x{r0[0,0]:.2f}_y{r0[0,1]:.2f}.png"
        )

        plt.savefig(nome_arquivo, dpi=200)
        plt.close()

        print(f"→ fator de contração = {fator:.3f}")
        print(f"Imagem salva em: {nome_arquivo}")

    return resultados
res = testar_convergencia_radial(
    nivel_max=6,
    N_particulas=100,
    r0=r0
)

plt.plot(res["nivel"], res["fator_contracao"], "-o")
plt.axhline(1, ls="--", c="k")
plt.xlabel("nível n")
plt.ylabel("R_final / R_inicial")
plt.grid(alpha=0.3)
# Out:
# Testando convergência radial para n = 1
# → fator de contração = 1.861
# Imagem salva em: convergencia_radial_2/convergencia_radial_n1_x0.53_y0.40.png
#
# Testando convergência radial para n = 2
# → fator de contração = 1.038
# Imagem salva em: convergencia_radial_2/convergencia_radial_n2_x0.53_y0.40.png
#
# Testando convergência radial para n = 3
# → fator de contração = 1.149
# Imagem salva em: convergencia_radial_2/convergencia_radial_n3_x0.53_y0.40.png
#
# Testando convergência radial para n = 4
# → fator de contração = 1.134
# Imagem salva em: convergencia_radial_2/convergencia_radial_n4_x0.53_y0.40.png
#
# Testando convergência radial para n = 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[159], line 138
#     135         print(f"Imagem salva em: {nome_arquivo}")
#     137     return resultados
# --> 138 res = testar_convergencia_radial(
#     139     nivel_max=6,
#     140     N_particulas=100,
#     141     r0=r0
#     142 )
#     144 plt.plot(res["nivel"], res["fator_contracao"], "-o")
#     145 plt.axhline(1, ls="--", c="k")
#
# Cell In[159], line 40, in testar_convergencia_radial(nivel_max, N_particulas, r0, pasta_saida, nivel_min, usar_raio)
#      37 dt = 0.08 * R(n)
#      38 t_max = 5
# ---> 40 ts, rs = simular_particulas_2(
#      41     N=N_particulas,
#      42     N_fields=n,
#      43     dimensao_quadrado=L,
#      44     r0=r0,
#      45     dt=dt,
#      46     t_max=t_max
#      47 )
#      49 # Pontos iniciais e finais
#      50 r_ini = rs[0,:,:]      # (N, 2)
#
# Cell In[158], line 135, in simular_particulas_2(N, N_fields, dimensao_quadrado, r0, dt, t_max)
#     132 # adiciona a partícula central exatamente em r0
#     133 particle_t0 = np.vstack((r0,particle_t0))
# --> 135 t, r = solve_RK4(funcao, particle_t0, 0.0, dt, t_max)
#     136 return t, r
#
# Cell In[4], line 24, in solve_RK4(func, r0, t0, dt, t_max)
#      21 ri = r[i]
#      23 k1 = func(ti, ri)
# ---> 24 k2 = func(ti + dt/2, ri + dt/2*k1)
#      25 k3 = func(ti + dt/2, ri + dt/2*k2)
#      26 k4 = func(ti + dt,   ri + dt*k3)
#
# Cell In[158], line 114, in simular_particulas_2.<locals>.funcao(t, r)
#     112 x = r[:, 0]
#     113 y = r[:, 1]
# --> 114 Vx, Vy = campo_total_2(x, y, t, N_fields)
#     115 return np.column_stack((Vx, Vy))
#
# Cell In[158], line 42, in campo_total_2(x, y, t, n_max)
#      40 for n in range(1, n_max + 1):
#      41     for idx in indices_nivel(n):
# ---> 42         vx, vy = campo_2(x, y, t, n, list(idx))
#      43         Vx += vx
#      44         Vy += vy
#
# Cell In[158], line 6, in campo_2(x, y, t, n, index)
#       1 def campo_2(x, y, t, n, index):
#       2     """
#       3     Campo vetorial induzido por um único centro
#       4     do nível n nos pontos (x, y).
#       5     """
# ----> 6     x_centro_n = x_centros(n, index, t)
#       8     # Diferenças vetoriais (arrays)
#       9     dx = x - x_centro_n[0]
#
# Cell In[32], line 51, in x_centros(n, index, t)
#      46     raise ValueError("Erro de tamanho de array")
#      48 # Deslocamento circular do centro atual
#      49 diff = R(n) * np.sqrt(2) * np.array([
#      50     np.cos(Omega(n) * t + phi(n, index)),
# ---> 51     np.sin(Omega(n) * t + phi(n, index))
#      52 ])
#      54 # Soma com o centro do nível anterior
#      55 return diff + x_centros(n - 1, index[:-1], t)
#
# KeyboardInterrupt:

# %%
def testar_estabilidade_2(
    nivel_max,
    
    N_particulas,
    r0,
    pasta_saida="estabilidade_2",
    nivel_min = 1
):
    """
    Testa a estabilidade do ponto r0 para diferentes números de níveis do campo.
    Para cada nível n:
      - simula uma nuvem de partículas ao redor de r0
      - plota as trajetórias
      - salva a figura em disco
    """

    os.makedirs(pasta_saida, exist_ok=True)

    for n in tqdm(
        range(nivel_min, nivel_max + 1),
        desc="Testando níveis",
        unit="nível"
    ):


        # Escalas naturais do nível
        L = R(n)/16         # tamanho da nuvem inicial
        dt = 0.08 * R(n)             # passo temporal
        t_max = 5         # tempo total (alguns períodos)

        print(f"Testando estabilidade para n = {n}")

        ts, rs = simular_particulas_2(
            N=N_particulas,
            N_fields=n,
            dimensao_quadrado=L,
            r0=r0,
            dt=dt,
            t_max=t_max
        )

        # rs tem shape (Nt, N, 2)
        Nt = rs.shape[0]

        plt.figure(figsize=(6, 6))


        cores = plt.cm.viridis(np.linspace(0, 1, N_particulas))

        for i in range(N_particulas):
            # Trajetória
            plt.plot(
                rs[:, i, 0],
                rs[:, i, 1],
                lw=1,
                alpha=0.4,
                color=cores[i]
            )

            # Ponto inicial (vazado)
            plt.scatter(
                rs[0, i, 0],
                rs[0, i, 1],
                facecolors="none",
                edgecolors=cores[i],
                s=30,
                linewidths=1.5
            )

            # Ponto final (bem visível)
            plt.scatter(
                rs[-1, i, 0],
                rs[-1, i, 1],
                color=cores[i],
                s=30,
                zorder=3
            )

        # Ponto central
        plt.scatter(
            r0[0, 0],
            r0[0, 1],
            c="red",
            s=100,
            marker="x",
            linewidths=2,
            label="ponto r0"
        )

        plt.axis("equal")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title(f"Estabilidade em torno de r0 — Níveis até n = {n}")
        plt.legend()
        plt.grid(alpha=0.3)


        nome_arquivo = os.path.join(
            pasta_saida,
            f"estabilidade_nivel_{n}_em_x{r0[0,0]:.3f}_y{r0[0,1]:.2f}em.png"
        )
        plt.savefig(nome_arquivo, dpi=200)
        plt.close()

        print(f"Imagem salva em: {nome_arquivo}")

r0 = np.array([[-.2, .1]])

testar_estabilidade_2(
    nivel_max=5,
    N_particulas=50,
    r0=r0,
    nivel_min = 1
)
# Out:
# Testando níveis:   0%|          | 0/5 [00:00<?, ?nível/s]
# Testando estabilidade para n = 1
# Testando níveis:  20%|██        | 1/5 [00:00<00:01,  3.78nível/s]
# Imagem salva em: estabilidade_2/estabilidade_nivel_1_em_x-0.200_y0.10em.png
# Testando estabilidade para n = 2
# Testando níveis:  40%|████      | 2/5 [00:00<00:00,  3.62nível/s]
# Imagem salva em: estabilidade_2/estabilidade_nivel_2_em_x-0.200_y0.10em.png
# Testando estabilidade para n = 3
# Testando níveis:  60%|██████    | 3/5 [00:01<00:00,  2.47nível/s]
# Imagem salva em: estabilidade_2/estabilidade_nivel_3_em_x-0.200_y0.10em.png
# Testando estabilidade para n = 4
# Testando níveis:  80%|████████  | 4/5 [00:03<00:01,  1.34s/nível]
# Imagem salva em: estabilidade_2/estabilidade_nivel_4_em_x-0.200_y0.10em.png
# Testando estabilidade para n = 5
# Testando níveis: 100%|██████████| 5/5 [00:26<00:00,  5.36s/nível]
# Imagem salva em: estabilidade_2/estabilidade_nivel_5_em_x-0.200_y0.10em.png

# %%
def testar_estabilidade_2_static(
    nivel_max,
    
    N_particulas,
    r0,
    pasta_saida="estabilidade_2_static",
    nivel_min = 1
):
    """
    Testa a estabilidade do ponto r0 para diferentes números de níveis do campo.
    Para cada nível n:
      - simula uma nuvem de partículas ao redor de r0
      - plota as trajetórias
      - salva a figura em disco
    """

    os.makedirs(pasta_saida, exist_ok=True)

    for n in tqdm(
        range(nivel_min, nivel_max + 1),
        desc="Testando níveis",
        unit="nível"
    ):


        # Escalas naturais do nível
        L = R(n)/16         # tamanho da nuvem inicial
        dt = 0.08 * R(n)             # passo temporal
        t_max = 10         # tempo total (alguns períodos)

        print(f"Testando estabilidade para n = {n}")

        ts, rs = simular_particulas_2_static(
            N=N_particulas,
            N_fields=n,
            dimensao_quadrado=L,
            r0=r0,
            dt=dt,
            t_max=t_max
        )

        # rs tem shape (Nt, N, 2)
        Nt = rs.shape[0]

        plt.figure(figsize=(6, 6))


        cores = plt.cm.viridis(np.linspace(0, 1, N_particulas))

        for i in range(N_particulas):
            # Trajetória
            plt.plot(
                rs[:, i, 0],
                rs[:, i, 1],
                lw=1,
                alpha=0.4,
                color=cores[i]
            )

            # Ponto inicial (vazado)
            plt.scatter(
                rs[0, i, 0],
                rs[0, i, 1],
                facecolors="none",
                edgecolors=cores[i],
                s=30,
                linewidths=1.5
            )

            # Ponto final (bem visível)
            plt.scatter(
                rs[-1, i, 0],
                rs[-1, i, 1],
                color=cores[i],
                s=30,
                zorder=3
            )

        # Ponto central
        plt.scatter(
            r0[0, 0],
            r0[0, 1],
            c="red",
            s=100,
            marker="x",
            linewidths=2,
            label="ponto r0"
        )

        plt.axis("equal")
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title(f"Estabilidade em torno de r0 — Níveis até n = {n}")
        plt.legend()
        plt.grid(alpha=0.3)


        nome_arquivo = os.path.join(
            pasta_saida,
            f"estabilidade_nivel_{n}_em_x{r0[0,0]:.3f}_y{r0[0,1]:.2f}em.png"
        )
        plt.savefig(nome_arquivo, dpi=200)
        plt.close()

        print(f"Imagem salva em: {nome_arquivo}")

r0 = np.array([[.2, -.0]])

testar_estabilidade_2_static(
    nivel_max=5,
    N_particulas=50,
    r0=r0,
    nivel_min = 1
)
# Out:
# Testando níveis:   0%|          | 0/5 [00:00<?, ?nível/s]
# Testando estabilidade para n = 1
# Testando níveis:  20%|██        | 1/5 [00:00<00:01,  3.68nível/s]
# Imagem salva em: estabilidade_2_static/estabilidade_nivel_1_em_x0.200_y-0.00em.png
# Testando estabilidade para n = 2
# Testando níveis:  40%|████      | 2/5 [00:00<00:00,  3.10nível/s]
# Imagem salva em: estabilidade_2_static/estabilidade_nivel_2_em_x0.200_y-0.00em.png
# Testando estabilidade para n = 3
# Testando níveis:  60%|██████    | 3/5 [00:01<00:01,  1.88nível/s]
# Imagem salva em: estabilidade_2_static/estabilidade_nivel_3_em_x0.200_y-0.00em.png
# Testando estabilidade para n = 4
# Testando níveis:  80%|████████  | 4/5 [00:06<00:02,  2.34s/nível]
# Imagem salva em: estabilidade_2_static/estabilidade_nivel_4_em_x0.200_y-0.00em.png
# Testando estabilidade para n = 5
# Testando níveis: 100%|██████████| 5/5 [00:51<00:00, 10.25s/nível]
# Imagem salva em: estabilidade_2_static/estabilidade_nivel_5_em_x0.200_y-0.00em.png

# %% [markdown]
# # ======================================================================
# # TESTAR LYAPUNOV
# # ======================================================================

# %%
def lyapunov_maximo(
    r0,
    N_fields,
    dt=0.01,
    t_max=50,
    delta0=1e-6,
    n_renorm=10
):
    """
    Calcula o expoente de Lyapunov máximo usando
    renormalização periódica.
    """

    # condição inicial e perturbação
    theta = np.random.uniform(0, 2*np.pi)
    delta_vec = delta0 * np.array([np.cos(theta), np.sin(theta)])

    r = r0.copy()
    r_pert = r0 + delta_vec

    soma_logs = 0.0
    tempo_total = 0.0

    for _ in range(int(t_max / (n_renorm * dt))):

        # empilha as duas partículas
        r_init = np.vstack([r, r_pert])

        def funcao(t, R):
            x = R[:, 0]
            y = R[:, 1]
            Vx, Vy = campo_total(x, y, t, N_fields)
            return np.column_stack((Vx, Vy))

        _, R = solve_RK4(
            funcao,
            r_init,
            0.0,
            dt,
            n_renorm * dt
        )

        r = R[-1, 0]
        r_pert = R[-1, 1]

        delta = r_pert - r
        dist = np.linalg.norm(delta)

        soma_logs += np.log(dist / delta0)
        tempo_total += n_renorm * dt

        # renormalização
        delta = delta / dist
        r_pert = r + delta0 * delta

    return soma_logs / tempo_total

for n in range(1, 9):
    lam = lyapunov_maximo(
        r0=np.array([np.pi/6, np.sqrt(2)/4]),
        N_fields=n,
        dt=0.01,
        t_max=80
    )
    print(f"Níveis = {n}, Lyapunov = {lam:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 60
#      56     return soma_logs / tempo_total
#      58 for n in range(1, 9):
#      59     lam = lyapunov_maximo(
# ---> 60         r0=np.array([np.pi/6, np.sqrt(2)/4]),
#      61         N_fields=n,
#      62         dt=0.01,
#      63         t_max=80
#      64     )
#      65     print(f"Níveis = {n}, Lyapunov = {lam:.4f}")
#
# NameError: name 'np' is not defined
